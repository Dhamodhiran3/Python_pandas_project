# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.1

# %%
df=pd.read_csv('C:/Users/Smart/Downloads/delta_airways_reviews.csv')

# %%
print(df)
# Out:
#      published_platform  rating    type  helpful_votes  travel_date  \
# 0               Desktop       2  review              0          NaN
# 1               Desktop       1  review              0          NaN
# 2               Desktop       1  review              0          NaN
# 3               Desktop       1  review              0          NaN
# 4               Desktop       5  review              0          NaN
# ...                 ...     ...     ...            ...          ...
# 2815            Desktop       1  review              1          NaN
# 2816            Desktop       5  review              1          NaN
# 2817            Desktop       3  review              1          NaN
# 2818            Desktop       1  review              1          NaN
# 2819            Desktop       5  review              1          NaN
#
#                                                    text  \
# 0     - [ ] we took off from SLC and were told the p...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      published_platform  rating    type  helpful_votes  travel_date  \
# 0               Desktop       2  review              0          NaN
# 1               Desktop       1  review              0          NaN
# 2               Desktop       1  review              0          NaN
# 3               Desktop       1  review              0          NaN
# 4               Desktop       5  review              0          NaN
# ...                 ...     ...     ...            ...          ...
# 2815            Desktop       1  review              1          NaN
# 2816            Desktop       5  review              1          NaN
# 2817            Desktop       3  review              1          NaN
# 2818            Desktop       1  review              1          NaN
# 2819            Desktop       5  review              1          NaN
#
#                                                    text  \
# 0     - [ ] we took off from SLC and were told the p...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      published_platform  rating    type  helpful_votes  travel_date  \
# 0               Desktop       2  review              0          NaN
# 1               Desktop       1  review              0          NaN
# 2               Desktop       1  review              0          NaN
# 3               Desktop       1  review              0          NaN
# 4               Desktop       5  review              0          NaN
# ...                 ...     ...     ...            ...          ...
# 2815            Desktop       1  review              1          NaN
# 2816            Desktop       5  review              1          NaN
# 2817            Desktop       3  review              1          NaN
# 2818            Desktop       1  review              1          NaN
# 2819            Desktop       5  review              1          NaN
#
#                                                    text  \
# 0     - [ ] we took off from SLC and were told the p...
# ...

# %%
df.head(55)
# Out:
#    published_platform  rating    type  helpful_votes  travel_date  \
# 0             Desktop       2  review              0          NaN
# 1             Desktop       1  review              0          NaN
# 2             Desktop       1  review              0          NaN
# 3             Desktop       1  review              0          NaN
# 4             Desktop       5  review              0          NaN
# 5             Desktop       1  review              0          NaN
# 6             Desktop       1  review              0          NaN
# 7             Desktop       1  review              0          NaN
# 8             Desktop       5  review              0          NaN
# 9             Desktop       1  review              0          NaN
# 10            Desktop       1  review              0          NaN
# 11            Desktop       1  review              1          NaN
# 12            Desktop       1  review              0          NaN
# ...

# %%
df.shape
# Out:
# (2820, 9)

# %%
df.columns
# Out:
# Index(['published_platform', 'rating', 'type', 'helpful_votes', 'travel_date',
#        'text', 'title', 'machine_translated', 'machine_translatable'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      published_platform  rating    type  helpful_votes  travel_date  \
# 0               Desktop       2  review              0          NaN
# 1               Desktop       1  review              0          NaN
# 2               Desktop       1  review              0          NaN
# 3               Desktop       1  review              0          NaN
# 4               Desktop       5  review              0          NaN
# ...                 ...     ...     ...            ...          ...
# 2815            Desktop       1  review              1          NaN
# 2816            Desktop       5  review              1          NaN
# 2817            Desktop       3  review              1          NaN
# 2818            Desktop       1  review              1          NaN
# 2819            Desktop       5  review              1          NaN
#
#                                                    text  \
# 0     - [ ] we took off from SLC and were told the p...
# ...

# %%
df.count()
# Out:
# published_platform      2820
# rating                  2820
# type                    2820
# helpful_votes           2820
# travel_date                0
# text                    2820
# title                   2819
# machine_translated      2820
# machine_translatable    2820
# dtype: int64

# %%
 df['helpful_votes'].unique()
# Out:
# array([ 0,  1,  2,  5, 28,  3,  4, 14,  9, 35,  6, 20, 15], dtype=int64)

# %%
import plotly.express as px

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('helpful_votes')['text'].sum().sort_values(ascending=True).head(10)
# Out:
# helpful_votes
# 0     - [ ] we took off from SLC and were told the p...
# 4     Active Duty Military family traveling on activ...
# 28    Dang Delta! At one point in time, you were nai...
# 2     For the amount of money spent to sit in delta ...
# 15    Horrible airline they do not care about their ...
# 20    I traveled from JFK to Amsterdam on Delta's A3...
# 5     I travelled on the redeye flight overnight fro...
# 35    I"ve been happy with Delta.  I see a lot of se...
# 6     Paid extra to fly Premium Select (BTW, no sele...
# 1     Supposed to be on a direct flight to Atlanta t...
# Name: text, dtype: object

# %%
df.groupby('helpful_votes')['title'].sum().sort_values(ascending=False).head(10)
# Out:
# helpful_votes
# 15                                   Worst airline ever
# 4     WORST CUSTOMER SERVICE EVERLook Before You Boo...
# 9     Timely flight but mediocre business class service
# 2     Sitting where vomit and mucus was4 hours and c...
# 6     Premium SelectExcellent FlightTerrible first c...
# 3     Lost baggage, no updates in 24 daysWorst trave...
# 35                                 I'm Happy with Delta
# 5     I wish the flight attendants would talk less o...
# 14                        Don’t ever fly with lynx air.
# 28                                         Disappointed
# Name: title, dtype: object

# %%
df.machine_translated<=10
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2815    True
# 2816    True
# 2817    True
# 2818    True
# 2819    True
# Name: machine_translated, Length: 2820, dtype: bool

# %%
import matplotlib.pyplot as plt

# Data
counts = [2820, 2820, 2820, 2820, 0, 2820, 2819, 2820, 2820]

# Labels for each category
labels = ['published_platform', 'rating', 'type', 'helpful_votes', 'travel_date', 'text', 'title', 'machine_translated', 'machine_translatable']

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Categories')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
plt.figure(figsize=(10, 6))
plt.hist(df['rating'], bins=20, color='skyblue', edgecolor='black')
plt.title('Delta Airways Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your data is stored in a DataFrame named 'df'
# Replace 'df' with the name of your DataFrame if it's different

# Extracting necessary columns
published_platform = df['published_platform']
rating = df['rating']
helpful_votes = df['helpful_votes']

# Creating scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(helpful_votes, rating, color='skyblue', alpha=0.5)
plt.title('Scatter Plot of Rating vs Helpful Votes')
plt.xlabel('Helpful Votes')
plt.ylabel('Rating')
plt.grid(True)
plt.show()
